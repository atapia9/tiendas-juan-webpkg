# %% [markdown]
# # Informe en Colab — Análisis de Tiendas
# **Objetivo:** evaluar 4 tiendas para ayudar al Sr. Juan a decidir cuál vender.
#
# **Criterios analizados:** Facturación total, categorías populares, calificación promedio, productos más/menos vendidos, y costo promedio de envío.
#
# _Generado:_ 2025-10-20 03:01

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda1_df = pd.read_csv(url)
tienda2_df = pd.read_csv(url2)
tienda3_df = pd.read_csv(url3)
tienda4_df = pd.read_csv(url4)

# Add a 'tienda' column to each dataframe
tienda1_df['tienda'] = 'tienda_1'
tienda2_df['tienda'] = 'tienda_2'
tienda3_df['tienda'] = 'tienda_3'
tienda4_df['tienda'] = 'tienda_4'

# Concatenate the dataframes
df_all = pd.concat([tienda1_df, tienda2_df, tienda3_df, tienda4_df], ignore_index=True)

df_all.head()
# Out:
#             Producto Categoría del Producto     Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos 164,300.00        6,900.00
# 1    Mesa de comedor                Muebles 192,300.00        8,400.00
# 2      Juego de mesa               Juguetes 209,600.00       15,900.00
# 3         Microondas      Electrodomésticos 757,500.00       41,000.00
# 4   Silla de oficina                Muebles 335,200.00       20,200.00
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas   lat    lon    tienda
# 0  Tarjeta de crédito                   8  4.61 -74.08  tienda_1
# ...

# %%
#@title 1) Preparación del entorno (librerías)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option("display.float_format", lambda x: f"{x:,.2f}")
print("Entorno listo.")
# Out:
# Entorno listo.

# %% [markdown]
# ## 2) Cargar datos
# Elige una opción:
# 1) **Subir archivos** (`tienda_1 .csv`, `tienda_2.csv`, `tienda_3.csv`, `tienda_4.csv`).
# 2) **Usar rutas locales** si ya están en el entorno (ajusta los paths si es necesario).

# %%
#@title Opción A: Subir archivos (recomendado en Colab)
#@markdown Sube exactamente 4 archivos con nombres: `tienda_1 .csv`, `tienda_2.csv`, `tienda_3.csv`, `tienda_4.csv`
USE_UPLOAD = True #@param {type:"boolean"}
if USE_UPLOAD:
    from google.colab import files
    uploaded = files.upload()
    files_list = sorted([name for name in uploaded.keys() if name.lower().endswith(".csv") and name.lower().startswith("tienda")])
else:
    files_list = None

files_list
# Out:
#      <input type="file" id="files-1bf1a98e-684f-4cc5-95eb-4e3fedbaa0c2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1bf1a98e-684f-4cc5-95eb-4e3fedbaa0c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#@title Opción B: Usar archivos locales
#@markdown Ajusta las rutas si tus nombres o ubicaciones difieren.
DEFAULT_PATHS = [
    "/content/tienda_1 .csv",
    "/content/tienda_2.csv",
    "/content/tienda_3.csv",
    "/content/tienda_4.csv",
]

# Si ya existen en el entorno actual (como en esta sesión), intenta encontrarlos también:
import os
# Check if files_list is defined before using it
if 'files_list' not in locals() or files_list is None:
    candidates = [f for f in os.listdir('.') if f.lower().endswith('.csv') and f.lower().startswith('tienda')]
    if candidates:
        DEFAULT_PATHS = sorted(candidates)

DEFAULT_PATHS
# Out:
# ['/content/tienda_1 .csv',
#  '/content/tienda_2.csv',
#  '/content/tienda_3.csv',
#  '/content/tienda_4.csv']

# %% [markdown]
# ## 4) Métricas principales

# %%
# Facturación total por tienda
facturacion = df_all.groupby("tienda", as_index=False)["Precio"].sum().rename(columns={"Precio":"Facturación Total"}).sort_values("Facturación Total", ascending=False)
facturacion
# Out:
#      tienda  Facturación Total
# 0  tienda_1   1,150,880,400.00
# 1  tienda_2   1,116,343,500.00
# 2  tienda_3   1,098,019,600.00
# 3  tienda_4   1,038,375,700.00
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# facturacion['Facturación Total'].plot(kind='hist', bins=20, title='Facturación Total')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# facturacion.groupby('tienda').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
# ...

# %%
# Categorías populares (Top 3 por tienda, por conteo)
cat_pop = (df_all.groupby(["tienda","Categoría del Producto"]).size().reset_index(name="Compras")
           .sort_values(["tienda","Compras"], ascending=[True, False]))
top3_categorias = cat_pop.groupby("tienda").head(3).reset_index(drop=True)
top3_categorias
# Out:
#       tienda Categoría del Producto  Compras
# 0   tienda_1                Muebles      465
# 1   tienda_1           Electrónicos      448
# 2   tienda_1               Juguetes      324
# 3   tienda_2                Muebles      442
# 4   tienda_2           Electrónicos      422
# 5   tienda_2               Juguetes      313
# 6   tienda_3                Muebles      499
# 7   tienda_3           Electrónicos      451
# 8   tienda_3               Juguetes      315
# 9   tienda_4                Muebles      480
# 10  tienda_4           Electrónicos      451
# 11  tienda_4               Juguetes      338

# %%
# Productos más y menos vendidos por tienda (por número de compras)
prod_counts = df_all.groupby(["tienda","Producto"]).size().reset_index(name="Compras")
idx_max = prod_counts.groupby("tienda")["Compras"].idxmax()
idx_min = prod_counts.groupby("tienda")["Compras"].idxmin()
mas_vendidos = prod_counts.loc[idx_max].reset_index(drop=True).rename(columns={"Producto":"Producto Más Vendido","Compras":"Compras (Más)"})
menos_vendidos = prod_counts.loc[idx_min].reset_index(drop=True).rename(columns={"Producto":"Producto Menos Vendido","Compras":"Compras (Menos)"})
mas_vendidos, menos_vendidos
# Out:
# (     tienda       Producto Más Vendido  Compras (Más)
#  0  tienda_1                    Armario             60
#  1  tienda_2  Iniciando en programación             65
#  2  tienda_3              Kit de bancas             57
#  3  tienda_4                   Cama box             62,
#       tienda     Producto Menos Vendido  Compras (Menos)
#  0  tienda_1  Auriculares con micrófono               33
#  1  tienda_2              Juego de mesa               32
#  2  tienda_3    Bloques de construcción               35
#  3  tienda_4         Guitarra eléctrica               33)

# %%
# Costo promedio de envío por tienda
envio_prom = df_all.groupby("tienda", as_index=False)["Costo de envío"].mean().rename(columns={"Costo de envío":"Costo Promedio de Envío"})
envio_prom["Costo Promedio de Envío"] = envio_prom["Costo Promedio de Envío"].round(2)
envio_prom.sort_values("Costo Promedio de Envío")
# Out:
#      tienda  Costo Promedio de Envío
# 3  tienda_4                23,459.46
# 2  tienda_3                24,805.68
# 1  tienda_2                25,216.24
# 0  tienda_1                26,018.61

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(_df_60['tienda'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(_df_60, x='Costo Promedio de Envío', y='tienda', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# /tmp/ipython-input-2788369157.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(_df_60, x='Costo Promedio de Envío', y='tienda', inner='stick', palette='Dark2')

# %% [markdown]
# ## 5) Visualizaciones

# %%
# Facturación total por tienda
plt.figure()
plt.bar(facturacion["tienda"], facturacion["Facturación Total"])
plt.title("Facturación total por tienda")
plt.xlabel("Tienda"); plt.ylabel("Facturación total")
plt.tight_layout(); plt.show()

# %%
# Calificación promedio por tienda
plt.figure()
plt.bar(prom_eval["tienda"], prom_eval["Calificación Promedio"])
plt.title("Calificación promedio por tienda")
plt.xlabel("Tienda"); plt.ylabel("Calificación promedio")
plt.tight_layout(); plt.show()

# %%
# Costo de envío promedio por tienda
plt.figure()
plt.bar(envio_prom["tienda"], envio_prom["Costo Promedio de Envío"])
plt.title("Costo promedio de envío por tienda")
plt.xlabel("Tienda"); plt.ylabel("Costo promedio de envío")
plt.tight_layout(); plt.show()

# %%
# Top 3 categorías por tienda (gráfico por tienda)
for tienda, sub in top3_categorias.groupby("tienda"):
    plt.figure()
    plt.barh(sub["Categoría del Producto"], sub["Compras"])
    plt.title(f"Top 3 categorías - {tienda}")
    plt.xlabel("Compras"); plt.ylabel("Categoría")
    plt.tight_layout(); plt.show()

# %% [markdown]
# ## 6) Marco de decisión (scorecard)
# Se pondera cada tienda con 3 factores:
#
# - **Facturación** (más es mejor) — peso 0.5
# - **Calificación** (más es mejor) — peso 0.3
# - **Costo de envío** (menos es mejor) — peso 0.2
#
# Normalizamos cada métrica (0–1) y calculamos un puntaje compuesto. La **candidata a vender** será la de **menor puntaje**.

# %%
# Normalización [0,1]
def minmax(s, invert=False):
    s = s.astype(float)
    m, M = s.min(), s.max()
    if M == m:
        return pd.Series(np.ones(len(s))*0.5, index=s.index)
    z = (s - m) / (M - m)
    return (1 - z) if invert else z

# Calculate prom_eval and facturacion here
prom_eval = df_all.groupby("tienda", as_index=False)["Calificación"].mean().rename(columns={"Calificación":"Calificación Promedio"})
facturacion = df_all.groupby("tienda", as_index=False)["Precio"].sum().rename(columns={"Precio":"Facturación Total"}).sort_values("Facturación Total", ascending=False)

sc = facturacion.merge(prom_eval, on="tienda").merge(envio_prom, on="tienda")
sc["fact_n"] = minmax(sc["Facturación Total"])
sc["calif_n"] = minmax(sc["Calificación Promedio"])
sc["envio_n"] = minmax(sc["Costo Promedio de Envío"], invert=True)

w_fact, w_calif, w_envio = 0.5, 0.3, 0.2
sc["score"] = w_fact*sc["fact_n"] + w_calif*sc["calif_n"] + w_envio*sc["envio_n"]
sc_sorted = sc.sort_values("score", ascending=False)  # mayor score = mejor tienda
sc_sorted[["tienda","Facturación Total","Calificación Promedio","Costo Promedio de Envío","fact_n","calif_n","envio_n","score"]]
# Out:
#      tienda  Facturación Total  Calificación Promedio  \
# 1  tienda_2   1,116,343,500.00                   4.04
# 2  tienda_3   1,098,019,600.00                   4.05
# 0  tienda_1   1,150,880,400.00                   3.98
# 3  tienda_4   1,038,375,700.00                   4.00
#
#    Costo Promedio de Envío  fact_n  calif_n  envio_n  score
# 1                25,216.24    0.69     0.85     0.31   0.66
# 2                24,805.68    0.53     1.00     0.47   0.66
# 0                26,018.61    1.00     0.00     0.00   0.50
# 3                23,459.46    0.00     0.27     1.00   0.28

# %%
from matplotlib import pyplot as plt
_df_66.plot(kind='scatter', x='Facturación Total', y='Calificación Promedio', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Recomendación
best = sc_sorted.iloc[0]
worst = sc_sorted.iloc[-1]
print(f"Mejor tienda (retener/impulsar): {best['tienda']} — score={best['score']:.3f}")
print(f"Candidata a vender: {worst['tienda']} — score={worst['score']:.3f}")
# Out:
# Mejor tienda (retener/impulsar): tienda_2 — score=0.666
# Candidata a vender: tienda_4 — score=0.286

# %% [markdown]
# ## 7) Resumen ejecutivo (para el Sr. Juan)

# %%
# Construir un resumen ejecutable con hallazgos clave
top_rev = facturacion.iloc[0]
low_rev = facturacion.iloc[-1]
best_cal = prom_eval.sort_values("Calificación Promedio", ascending=False).iloc[0]
low_ship = envio_prom.sort_values("Costo Promedio de Envío").iloc[0]

print("—"*60)
print("RESUMEN EJECUTIVO")
print("—"*60)
print(f"• Mayor facturación: {top_rev['tienda']} (MXN {top_rev['Facturación Total']:,.0f})")
print(f"• Menor facturación: {low_rev['tienda']} (MXN {low_rev['Facturación Total']:,.0f})")
print(f"• Mejor calificación promedio: {best_cal['tienda']} ({best_cal['Calificación Promedio']:.2f})")
print(f"• Envío promedio más barato: {low_ship['tienda']} (MXN {low_ship['Costo Promedio de Envío']:,.2f})")
print()
print(f"• Recomendación: vender {worst['tienda']} (score={worst['score']:.3f}).")
print("  *Justificación:* combina menor desempeño relativo en el scorecard,")
print("  integrando ventas, satisfacción del cliente y costos logísticos.")
print("—"*60)
# Out:
# ————————————————————————————————————————————————————————————
# RESUMEN EJECUTIVO
# ————————————————————————————————————————————————————————————
# • Mayor facturación: tienda_1 (MXN 1,150,880,400)
# • Menor facturación: tienda_4 (MXN 1,038,375,700)
# • Mejor calificación promedio: tienda_3 (4.05)
# • Envío promedio más barato: tienda_4 (MXN 23,459.46)
#
# • Recomendación: vender tienda_4 (score=0.286).
#   *Justificación:* combina menor desempeño relativo en el scorecard,
#   integrando ventas, satisfacción del cliente y costos logísticos.
# ————————————————————————————————————————————————————————————

# %% [markdown]
# # ETL mínimo: datos crudos → `df`
# Lee todos los CSV/XLSX de `../data/raw/`, normaliza columnas, tipifica numéricos, une y deduplica.

# %%
# %%
import os, glob, pandas as pd, numpy as np

# RAW_DIR = os.path.normpath(os.path.join("..", "data", "raw"))
RAW_DIR = "/content/" # Update RAW_DIR to look in /content/
INTERMEDIATE_DIR = os.path.normpath(os.path.join("..", "data"))
os.makedirs(RAW_DIR, exist_ok=True)

print("📂 Carpeta de entrada:", RAW_DIR)

RENAME_RULES = {
    r"tienda|sucursal|store|shop": "tienda",
    r"categor[ií]a|category": "categoria",
    r"producto|product|item": "producto",
    r"facturaci[oó]n|revenue|ventas|importe|monto|total": "facturacion",
    r"calificaci[oó]n|evaluaci[oó]n|rating|score": "evaluacion",
    r"(costo.*env[ií]o)|(shipping.*cost)|(env[ií]o)": "costo_envio",
    r"cantidad|unidades|qty|quantity|ventas_n|n_ventas": "cantidad",
    r"^lat(itud)?$|latitude": "lat",
    r"^lon(gitud)?$|long|longitude": "lon"
}
def normalize_columns(cols):
    out = []
    import re
    for c in cols:
        lc = c.strip().lower().replace(" ", "_")
        newc = lc
        for pat, target in RENAME_RULES.items():
            if re.search(pat, lc, flags=re.IGNORECASE):
                newc = target
                break
        out.append(newc)
    return out
def coerce_numeric(s):
    if s.dtype.kind in "biufc":
        return s
    return (s.astype(str)
              .str.replace(r"[^\d,\.\-]", "", regex=True)
              .str.replace(",", ".", regex=False)
              .replace({"": np.nan, ".": np.nan})
              .astype(float))

files = glob.glob(os.path.join(RAW_DIR, "**", "*.csv"), recursive=True) + \
        glob.glob(os.path.join(RAW_DIR, "**", "*.xlsx"), recursive=True) + \
        glob.glob(os.path.join(RAW_DIR, "**", "*.xls"), recursive=True)

if not files:
    print("⚠️ No se encontraron archivos en", RAW_DIR, " — coloca aquí tus CSV/XLSX y vuelve a ejecutar.")
else:
    print(f"Se encontraron {len(files)} archivos.")
frames = []
for path in files:
    try:
        if path.lower().endswith(".csv"):
            df_i = pd.read_csv(path, encoding="utf-8", engine="python")
        else:
            df_i = pd.read_excel(path, engine="openpyxl")
        df_i.columns = normalize_columns(df_i.columns)
        for cand in ["facturacion", "evaluacion", "costo_envio", "cantidad"]:
            if cand in df_i.columns:
                df_i[cand] = coerce_numeric(df_i[cand])
        frames.append(df_i)
        print("✔️ Cargado:", os.path.basename(path), df_i.shape)
    except Exception as e:
        print("❌ Error con", path, "→", e)
if frames:
    df = pd.concat(frames, ignore_index=True, sort=False).drop_duplicates()
    inter_csv = os.path.join(INTERMEDIATE_DIR, "df_intermedio.csv")
    df.to_csv(inter_csv, index=False, encoding="utf-8")
    print("🗂️ Intermedio guardado en:", inter_csv)
    display(df.head(10))
else:
    print("⚠️ No se creó el DataFrame `df` porque no hubo archivos válidos.")
# Out:
# 📂 Carpeta de entrada: /content/
# Se encontraron 8 archivos.
# ✔️ Cargado: tienda_4.csv (2358, 12)
# ✔️ Cargado: tienda_2.csv (2359, 12)
# ✔️ Cargado: tienda_3.csv (2359, 12)
# ✔️ Cargado: tienda_1 .csv (2359, 12)
# ✔️ Cargado: mnist_train_small.csv (19999, 785)
# ❌ Error con /content/sample_data/california_housing_test.csv → 'DataFrame' object has no attribute 'dtype'
# ❌ Error con /content/sample_data/california_housing_train.csv → 'DataFrame' object has no attribute 'dtype'
# ✔️ Cargado: mnist_test.csv (9999, 785)
# 🗂️ Intermedio guardado en: ../data/df_intermedio.csv
#                     producto               categoria       precio  \
# 0               Lavavajillas       Electrodomésticos 1,084,800.00
# 1                   Cama box                 Muebles   473,800.00
# 2        Balón de baloncesto    Deportes y diversión    23,700.00
# 3        Modelado predictivo                  Libros    57,700.00
# 4                Auriculares            Electrónicos   138,900.00
# ...

# %%
# %% [markdown]
# # Exportador de métricas para el sitio (GitHub Pages)

# %%
import json, os, pandas as pd
COLUMN_SYNONYMS = {
    "store": ["tienda", "store", "sucursal", "shop"],
    "category": ["categoria", "categoría", "category"],
    "product": ["producto", "product", "item"],
    "revenue": ["facturacion", "facturación", "revenue", "ventas_mxn", "monto", "total", "importe"],
    "rating": ["evaluacion", "evaluación", "rating", "calificacion", "calificación", "score"],
    "ship_cost": ["costo_envio", "costo_de_envio", "shipping_cost", "envio", "costo_logistico", "costo_logístico"],
    "qty": ["cantidad", "unidades", "qty", "quantity", "ventas", "n_ventas"]
}
def find_col(df, keys):
    cols = {c.lower(): c for c in df.columns}
    for k in keys:
        k = k.lower()
        if k in cols:
            return cols[k]
    for k in keys:
        for lc, orig in cols.items():
            if k in lc:
                return orig
    return None
def resolve_columns(df):
    mapping = {}
    for std, candidates in COLUMN_SYNONYMS.items():
        col = find_first(df, candidates)
        mapping[std] = col
    missing = [k for k, v in mapping.items() if v is None and k in ("store","revenue","rating","ship_cost","qty","category","product")]
    if len(missing) > 0:
        print("⚠️ Columnas no detectadas automáticamente:", missing)
    return mapping
try:
    df  # noqa: F821
except NameError:
    raise RuntimeError("No se encontró el DataFrame 'df'. Ejecuta el ETL primero.")
mapping = resolve_columns(df)
S = mapping["store"]; C = mapping["category"]; P = mapping["product"]
R = mapping["revenue"]; Q = mapping["qty"]; RT = mapping["rating"]; SC = mapping["ship_cost"]
d = df.copy()
stores = sorted(d[S].dropna().unique().tolist()) if S and S in d.columns else []
fact_by_store = d.groupby(S)[R].sum().reindex(stores).round(2).tolist() if (S and R and S in d.columns and R in d.columns) else [None]*len(stores)
eval_by_store = d.groupby(S)[RT].mean().reindex(stores).round(2).tolist() if (S and RT and S in d.columns and RT in d.columns) else [None]*len(stores)
ship_by_store = d.groupby(S)[SC].mean().reindex(stores).round(2).tolist() if (S and SC and S in d.columns and SC in d.columns) else [None]*len(stores)
categorias_top = {}
if S and C and S in d.columns and C in d.columns:
    if Q and Q in d.columns:
        tmp = d.groupby([S, C])[Q].sum().reset_index()
        qcol = Q
    else:
        tmp = d.groupby([S, C]).size().reset_index(name="__cnt__")
        qcol = "__cnt__"
    for st in stores:
        sub = tmp[tmp[S]==st].sort_values(qcol, ascending=False).head(5)
        categorias_top[st] = {row[C]: int(row[qcol]) for _, row in sub.iterrows()}
productos_extremos = {}
if S and P and S in d.columns and P in d.columns:
    if Q and Q in d.columns:
        tmp = d.groupby([S, P])[Q].sum().reset_index()
        qcol = Q
    else:
        tmp = d.groupby([S, P]).size().reset_index(name="__cnt__")
        qcol = "__cnt__"
    for st in stores:
        sub = tmp[tmp[S]==st].sort_values(qcol, ascending=False)
        top = sub.head(3)[P].tolist()
        bottom = sub.tail(2)[P].tolist() if len(sub)>=2 else sub.tail(1)[P].tolist()
        productos_extremos[st] = {"mas_vendidos": top, "menos_vendidos": bottom}
metrics = {
    "updated_at": pd.Timestamp.utcnow().isoformat(),
    "stores": stores,
    "facturacion_total": fact_by_store,
    "promedio_evaluacion": eval_by_store,
    "costo_envio_promedio": ship_by_store,
    "categorias_top": categorias_top,
    "productos_extremos": productos_extremos
}
out_path = os.path.normpath(os.path.join("..", "data", "metrics.json"))
os.makedirs(os.path.dirname(out_path), exist_ok=True)
with open(out_path, "w", encoding="utf-8") as f:
    json.dump(metrics, f, ensure_ascii=False, indent=2)
print("✅ Métricas exportadas a:", out_path)
# Removed the line causing the error: pd.DataFrame(metrics).to_csv(os.path.join(os.path.dirname(out_path), "metrics_flat.csv"), index=False, encoding="utf-8")
# Out:
# ⚠️ Columnas no detectadas automáticamente: ['store', 'revenue']
# ✅ Métricas exportadas a: ../data/metrics.json

# %%
import json
import os

# Define the path to the metrics.json file
metrics_path = os.path.normpath(os.path.join("..", "data", "metrics.json"))

# Check if the file exists before attempting to open it
if os.path.exists(metrics_path):
    # Load the JSON file
    with open(metrics_path, 'r', encoding='utf-8') as f:
        metrics_data = json.load(f)

    # Display the content
    print(json.dumps(metrics_data, indent=2, ensure_ascii=False))
else:
    print(f"Error: The file {metrics_path} was not found.")
# Out:
# {
#   "updated_at": "2025-10-20T07:01:50.847792+00:00",
#   "stores": [],
#   "facturacion_total": [],
#   "promedio_evaluacion": [],
#   "costo_envio_promedio": [],
#   "categorias_top": {},
#   "productos_extremos": {}
# }

# %% [markdown]
# # Análisis geográfico (opcional)
# Genera dispersión, heatmap (hexbin) y un **mapa Folium** con *MarkerCluster* y *HeatMap* a partir de columnas `lat`/`lon` (o sinónimos).

# %%
# %%
import os, math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

LAT_CANDIDATES = ["lat", "latitude", "latitud"]
LON_CANDIDATES = ["lon", "long", "longitude", "longitud"]
STORE_CANDS   = ["tienda", "store", "sucursal", "shop"]
REV_CANDS     = ["facturacion", "facturación", "revenue", "ventas_mxn", "monto", "total", "importe"]
RATE_CANDS    = ["evaluacion", "evaluación", "rating", "calificacion", "calificación", "score"]
CITY_CANDS = ["city", "ciudad", "lugar_de_compra"] # Added city candidates

def find_first(cols, cands):
    lower = {c.lower(): c for c in cols}
    for k in cands:
        if k in lower:
            return lower[k]
    for k in cands:
        for lc, orig in lower.items():
            if k in lc:
                return orig
    return None

assert 'df' in globals(), "Se requiere el DataFrame `df` (ejecuta el ETL)."

lat_col = find_first(df.columns, LAT_CANDIDATES)
lon_col = find_first(df.columns, LON_CANDIDATES)
store_col = find_first(df.columns, STORE_CANDS)
rev_col = find_first(df.columns, REV_CANDS)
rate_col = find_first(df.columns, RATE_CANDS)
city_col = find_first(df.columns, CITY_CANDS) # Find city column

if not lat_col or not lon_col:
    raise RuntimeError("No se detectaron columnas de latitud/longitud. Ajusta nombres o agrega columnas `lat` y `lon`.")

geo = df[[c for c in [store_col, lat_col, lon_col, rev_col, rate_col, city_col] if c in df.columns]].copy() # Include city column
geo = geo.dropna(subset=[lat_col, lon_col])
geo[lat_col] = pd.to_numeric(geo[lat_col], errors="coerce")
geo[lon_col] = pd.to_numeric(geo[lon_col], errors="coerce")
geo = geo.dropna(subset=[lat_col, lon_col])

assets_dir = os.path.normpath(os.path.join("..", "assets"))
os.makedirs(assets_dir, exist_ok=True)

# Dispersión por ciudad
plt.figure(figsize=(10,8)) # Increased figure size
if city_col and city_col in geo.columns:
    groups = geo.groupby(city_col)
    for name, g in groups:
        plt.scatter(g[lon_col], g[lat_col], s=14, alpha=0.6, label=str(name))
    plt.legend(title="Ciudad", fontsize=8) # Changed legend title to Ciudad
else:
    plt.scatter(geo[lon_col], geo[lat_col], s=14, alpha=0.6)
plt.title("Dispersión geográfica de transacciones por Ciudad") # Updated title
plt.xlabel("Longitud"); plt.ylabel("Latitud")
scatter_path = os.path.join(assets_dir, "geo_scatter_city.png") # Changed output filename
plt.tight_layout(); plt.savefig(scatter_path, dpi=140); plt.close()
print("📈 Dispersión guardada:", scatter_path)

# Heatmap hexbin
plt.figure(figsize=(7,6))
hb = plt.hexbin(geo[lon_col], geo[lat_col], gridsize=40, cmap="viridis", mincnt=1)
cb = plt.colorbar(hb); cb.set_label("Densidad")
plt.title("Mapa de calor (hexbin) de densidad de ventas")
plt.xlabel("Longitud"); plt.ylabel("Latitud")
hex_path = os.path.join(assets_dir, "geo_heatmap_hexbin_city.png") # Changed output filename
plt.tight_layout(); plt.savefig(hex_path, dpi=140); plt.close()
print("🔥 Heatmap hexbin guardado:", hex_path)

# Folium interactivo
try:
    import folium
    from folium.plugins import MarkerCluster, HeatMap
    center_lat = float(geo[lat_col].median())
    center_lon = float(geo[lon_col].median())
    m = folium.Map(location=[center_lat, center_lon], zoom_start=6, tiles="CartoDB positron")
    mc = MarkerCluster()
    if store_col and store_col in geo.columns: # Still keep store info in popup if available
        for _, r in geo.iterrows():
            popup = []
            if store_col: popup.append(f"<b>Tienda:</b> {r.get(store_col, '')}")
            if city_col: popup.append(f"<b>Ciudad:</b> {r.get(city_col, '')}") # Added city to popup
            if rev_col and rev_col in geo.columns and not pd.isna(r.get(rev_col)):
                try: popup.append(f"<b>Ingreso:</b> {float(r.get(rev_col)):.2f}")
                except: popup.append(f"<b>Ingreso:</b> {r.get(rev_col)}")
            if rate_col and rate_col in geo.columns and not pd.isna(r.get(rate_col)):
                try: popup.append(f"<b>Evaluación:</b> {float(r.get(rate_col)):.2f}")
                except: popup.append(f"<b>Evaluación:</b> {r.get(rate_col)}")
            folium.Marker([r[lat_col], r[lon_col]],
                          popup=folium.Popup("<br/>".join(popup) if popup else "Transacción", max_width=300),
                          icon=folium.Icon(color="blue", icon="shopping-cart", prefix="fa")).add_to(mc)
    else:
        for _, r in geo.iterrows():
            popup = []
            if city_col: popup.append(f"<b>Ciudad:</b> {r.get(city_col, '')}") # Added city to popup
            folium.Marker([r[lat_col], r[lon_col]],
                          popup=folium.Popup("<br/>".join(popup) if popup else "Transacción", max_width=300),
                          icon=folium.Icon(color="blue", icon="shopping-cart", prefix="fa")).add_to(mc)

    mc.add_to(m)
    if rev_col and rev_col in geo.columns:
        heat_data = geo[[lat_col, lon_col, rev_col]].dropna().values.tolist()
        vals = geo[rev_col].dropna().astype(float).values if len(geo[rev_col].dropna())>0 else []
        if len(vals) > 0 and np.nanmax(vals) > 0:
            maxv = np.nanpercentile(vals, 95)
            if maxv and maxv > 0:
                heat_data = [[lt, ln, min(float(rv)/maxv, 1.0)] for lt, ln, rv in heat_data]
        HeatMap(heat_data, radius=16, blur=22, min_opacity=0.3).add_to(m)
    else:
        HeatMap(geo[[lat_col, lon_col]].dropna().values.tolist(), radius=16, blur=22, min_opacity=0.3).add_to(m)
    folium_path = os.path.join(assets_dir, "ventas_mapa_city.html") # Changed output filename
    m.save(folium_path)
    print("🗺️ Mapa Folium guardado:", folium_path)
except Exception as e:
    print("⚠️ Folium no disponible o error al generar mapa:", e)

# Agregados espaciales por ciudad (binning simple)
if city_col and city_col in geo.columns:
    agg = geo.groupby([city_col]).size().reset_index(name="n") # Group by city
    if rev_col and rev_col in geo.columns:
        agg["revenue_sum"] = geo.groupby([city_col])[rev_col].sum().values # Group by city
    if rate_col and rate_col in geo.columns:
        agg["rating_mean"] = geo.groupby([city_col])[rate_col].mean().values # Group by city
    agg = agg.rename(columns={city_col:"ciudad"}) # Rename city column
    agg_path = os.path.join(assets_dir, "geo_city_agg.csv") # Changed output filename
    agg.to_csv(agg_path, index=False, encoding="utf-8")
    print("📊 Agregados espaciales guardados:", agg_path)
else:
     print("⚠️ Columna de ciudad no encontrada para agregados espaciales.")
# Out:
# 📈 Dispersión guardada: ../assets/geo_scatter_city.png
# 🔥 Heatmap hexbin guardado: ../assets/geo_heatmap_hexbin_city.png
# 🗺️ Mapa Folium guardado: ../assets/ventas_mapa_city.html
# 📊 Agregados espaciales guardados: ../assets/geo_city_agg.csv

# %%
display(sc_sorted)
# Out:
#      tienda  Facturación Total  Calificación Promedio  \
# 1  tienda_2   1,116,343,500.00                   4.04
# 2  tienda_3   1,098,019,600.00                   4.05
# 0  tienda_1   1,150,880,400.00                   3.98
# 3  tienda_4   1,038,375,700.00                   4.00
#
#    Costo Promedio de Envío  fact_n  calif_n  envio_n  score
# 1                25,216.24    0.69     0.85     0.31   0.66
# 2                24,805.68    0.53     1.00     0.47   0.66
# 0                26,018.61    1.00     0.00     0.00   0.50
# 3                23,459.46    0.00     0.27     1.00   0.28
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# sc_sorted['Facturación Total'].plot(kind='hist', bins=20, title='Facturación Total')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %% [markdown]
# ### Dispersión geográfica de transacciones

# %%
from IPython.display import Image
Image(filename='../assets/geo_scatter_city.png')

# %% [markdown]
# ### Mapa de calor (hexbin) de densidad de ventas

# %%
from IPython.display import Image
Image(filename='../assets/geo_heatmap_hexbin_city.png')

# %% [markdown]
# ### Mapa interactivo de ventas (Folium)
# Puedes ver el mapa interactivo haciendo clic [aquí](../assets/ventas_mapa.html).

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.bar(prom_eval["tienda"], prom_eval["Calificación Promedio"], color='lightgreen')
plt.title("Calificación Promedio por Tienda")
plt.xlabel("Tienda")
plt.ylabel("Calificación Promedio")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.bar(facturacion["tienda"], facturacion["Facturación Total"], color='skyblue')
plt.title("Facturación Total por Tienda")
plt.xlabel("Tienda")
plt.ylabel("Facturación Total")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
